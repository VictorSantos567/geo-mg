# %%
# !pip install geobr -q
# Out:
# WARNING: You are using pip version 21.2.3; however, version 23.0 is available.
# You should consider upgrading via the 'C:\Users\victo\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install geopandas -q
# Out:
# WARNING: You are using pip version 21.2.3; however, version 23.0 is available.
# You should consider upgrading via the 'C:\Users\victo\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import geobr

# %%
geobr.list_geobr()
# Out:
# Function: read_country
# Geographies available: Country
# Years available: 1872, 1900, 1911, 1920, 1933, 1940, 1950, 1960, 1970, 1980, 1991, 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_region
# Geographies available: Region
# Years available: 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_state
# Geographies available: States
# Years available: 1872, 1900, 1911, 1920, 1933, 1940, 1950, 1960, 1970, 1980, 1991, 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_meso_region
# Geographies available: Meso region
# Years available: 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_micro_region
# Geographies available: Micro region
# ...

# %%
censo_mg_2020=geobr.read_census_tract(code_tract='MG', year=2020)
# Out:
# c:\Users\victo\AppData\Local\Programs\Python\Python39\lib\site-packages\geopandas\array.py:93: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out

# %%
censo_mg_2020
# Out:
#          code_tract                                          zone  code_muni  \
# 0      3.100104e+14  Área Urbana de Alta Densidade de Edificações  3100104.0
# 1      3.100104e+14  Área Urbana de Alta Densidade de Edificações  3100104.0
# 2      3.100104e+14  Área Urbana de Alta Densidade de Edificações  3100104.0
# 3      3.100104e+14  Área Urbana de Alta Densidade de Edificações  3100104.0
# 4      3.100104e+14  Área Urbana de Alta Densidade de Edificações  3100104.0
# ...             ...                                           ...        ...
# 50501  3.172202e+14  Área Urbana de Alta Densidade de Edificações  3172202.0
# 50502  3.172202e+14            Área Rural (exclusive aglomerados)  3172202.0
# 50503  3.172202e+14            Área Rural (exclusive aglomerados)  3172202.0
# 50504  3.172202e+14            Área Rural (exclusive aglomerados)  3172202.0
# 50505  3.172202e+14            Área Rural (exclusive aglomerados)  3172202.0
#
# ...
